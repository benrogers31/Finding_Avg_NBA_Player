# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <h2> Here we are getting the data organized based on a specified starting year </h2>

# %%
#THIS IS THE YEAR WE WANT TO START AND FINISH CALCULATING THE AVERAGE FROM
start_year = 1980
end_year = 1990

# %%
all_players_df = pd.read_csv("csv_files/player_stats_"+str(start_year)+".csv")
all_players_df = all_players_df.drop_duplicates('NAME', keep='first')

for year in range(start_year+1, end_year+1):
    
    #store current year in df
    current_year_players_df = pd.read_csv("csv_files/player_stats_"+str(year)+".csv")

    #since some players were traded during each season their stats are split first showing TOT (total season)
    #and the following rows showing their stats specific for their teams
    #since the total is always first we can drop all duplicates following the first instance (ASSUMING NO PLAYERS HAVE THE SAME NAME)
    current_year_players_df = current_year_players_df.drop_duplicates('NAME', keep='first')
    
    #appending the current year to all previous years 
    all_players_df = all_players_df.append(current_year_players_df)
    
all_players_df
# Out:
#                      NAME  TEAM  POS  AGE   G   GS    MP    FG   FGA    FG%  \
# 0    Kareem Abdul-Jabbar*   LAL    C   32  82       38.3  10.2  16.9   .604
# 1           Tom Abernethy   GSW   PF   25  67       18.2   2.3   4.7   .481
# 2             Alvan Adams   PHO    C   25  75       28.9   6.2  11.7   .531
# 3         Tiny Archibald*   BOS   PG   31  80   80  35.8   4.8   9.9   .482
# 4           Dennis Awtrey   CHI    C   31  26       21.5   1.0   2.3   .450
# ..                    ...   ...  ...  ...  ..  ...   ...   ...   ...    ...
# 454     Orlando Woolridge   LAL   SF   30  62    2  22.9   4.9   8.9   .556
# 455      Haywoode Workman   ATL   PG   24   6    0   2.7   0.3   0.5   .667
# 456         James Worthy*   LAL   SF   28  80   80  37.0   8.9  16.2   .548
# 457           Danny Young   POR   PG   27  82    8  17.0   1.7   4.0   .421
# 458         Michael Young   LAC   SF   29  45    2  10.2   2.0   4.3   .474
#
#      ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    ...  0.765  2.3  8.5  10.8  4.5  1.0  3.4  3.6  2.6  24.8
# 1    ...  0.683  0.9  1.9   2.9  1.3  0.5  0.2  0.6  1.8   5.4
# 2    ...  0.797  2.1  6.0   8.1  4.3  1.4  0.7  2.9  3.2  14.9
# 3    ...  0.830  0.7  1.7   2.5  8.4  1.3  0.1  3.0  2.7  14.1
# 4    ...  0.640  1.1  3.3   4.4  1.5  0.5  0.6  1.0  2.5   3.3
# ..   ...    ...  ...  ...   ...  ...  ...  ...  ...  ...   ...
# 454  ...  0.733  0.8  2.2   3.0  1.5  0.6  0.7  1.2  2.6  12.7
# 455  ...  1.000  0.0  0.5   0.5  0.3  0.5  0.0  0.0  0.5   1.0
# 456  ...  0.782  2.0  4.0   6.0  3.6  1.2  0.6  2.0  2.4  21.1
# 457  ...  0.813  0.4  1.1   1.5  2.8  1.0  0.0  1.0  1.0   4.7
# 458  ...  0.711  0.8  1.1   1.9  0.5  0.6  0.1  0.3  1.0   4.9
#
# [3562 rows x 29 columns]

# %%
#HERE WE WILL SET CRITERIA FOR OUR DATA BASE AND GET RID OF NANs

#filling null values with 0
all_players_df = all_players_df.fillna(0)

# %% [markdown]
# <h2> Adding helper methods </h2>
# <p> The stats that we want from players to include are pts, reb, ast, stl, blk, tov, pf which are already in this data frame. But to make the most accurate comparisons we are going to want TS% 3PAr and FTr which are not in the df therefore have to be calculated. These helper methods make such calculations </p>

# %%
#Helper methods that take in the original data frame and output each stat 
def add_true_shooting(df):
    list_of_TS = []
    #goes through each row of the df and uses data to calculate each stat
    for index, player in df.iterrows():
        #this if statement prevents a divide by zero exception
        if(player['FGA']==0):
            list_of_TS.append(0.00000)
            continue
        ts = player['PTS']/(2*(player['FGA']+(0.44*player['FTA'])))
        #appends this calculated stat to the list 
        list_of_TS.append(ts)
    #adds list to dataframe with proper header    
    df['TS'] = list_of_TS
    return df

#these are methods are similar to the one above just implementing their own stat
def add_3PAr(df):
    list_of_3PAr = []
    for index, player in df.iterrows():
        if(player['FGA']==0):
            list_of_3PAr.append(0.00000)
            continue
        val = player['3PA']/player['FGA']
        list_of_3PAr.append(val)
       
    df['3PAr'] = list_of_3PAr
    return df

def add_FTr(df):
    list_of_FTr = []
    for index, player in df.iterrows():
        if(player['FGA']==0):
            list_of_FTr.append(0.00000)
            continue
        val = player['FTA']/player['FGA']
        list_of_FTr.append(val)
       
    df['FTr'] = list_of_FTr
    return df

# %% [markdown]
# <h2> Finding averages for player logistics </h2>

# %% [markdown]
# <h3> Looking at games played </h3>

# %%
#checking what is the average number of games played 
print("Average Games Played is: " + str(all_players_df['G'].mean()))

#tor_players_df.hist(column='GP').show()
plt.style.use('fivethirtyeight')

#making the plot 
gamesPlayedHist, g = plt.subplots()

g.hist(all_players_df['G'],color='red',bins=82)
g.set_xlabel("Games Played")
g.set_ylabel("Number of Players")
g.set_title("Distribution of Games Played per Season")
g.plot()
# Out:
# Average Games Played is: 60.120157215047726
# []

# %%
print(str(len(all_players_df.loc[all_players_df['G']== 81])))

all_players_df.loc[all_players_df['G']== 82].head(10)
# Out:
# 243
#                     NAME  TEAM  POS  AGE   G   GS    MP    FG   FGA    FG%  \
# 0   Kareem Abdul-Jabbar*   LAL    C   32  82       38.3  10.2  16.9   .604
# 7           Greg Ballard   WSB   SF   25  82       29.7   6.6  13.4   .495
# 20           Henry Bibby   PHI   PG   30  82       24.8   3.1   7.6   .401
# 21           Larry Bird*   BOS   PF   23  82   82  36.0   8.5  17.8   .474
# 22         Otis Birdsong   KCK   SG   24  82       35.2   9.5  18.9   .505
# 32        Dudley Bradley   IND   SG   22  82       24.7   3.4   7.4   .452
# 33            Mike Bratz   PHO   PG   24  82       19.4   3.3   8.4   .392
# 35            Ron Brewer   POR   SG   24  82       34.3   6.7  14.4   .464
# 37         Allan Bristow   UTA   SF   28  82       28.1   4.6   9.6   .480
# 54             M.L. Carr   BOS   SF   29  82    7  24.3   4.4   9.3   .474
#
#     ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...  0.765  2.3  8.5  10.8  4.5  1.0  3.4  3.6  2.6  24.8
# 7   ...  0.753  2.9  4.9   7.8  1.9  1.1  0.4  1.6  2.4  15.6
# 20  ...  0.790  0.8  1.7   2.5  3.7  0.8  0.1  1.8  2.0   9.0
# 21  ...  0.836  2.6  7.8  10.4  4.5  1.7  0.6  3.2  3.4  21.3
# 22  ...  0.694  2.1  2.0   4.0  2.5  1.7  0.3  2.2  2.8  22.7
# 32  ...  0.782  0.8  1.9   2.7  3.1  2.6  0.6  2.0  2.4   8.4
# 33  ...  0.870  0.6  1.4   2.0  2.7  1.1  0.1  1.6  2.0   8.5
# 35  ...  0.840  0.7  2.0   2.6  2.6  1.2  0.6  2.0  1.9  15.7
# 37  ...  0.811  2.1  4.2   6.2  4.2  1.1  0.1  2.2  2.6  11.6
# 54  ...  0.739  1.3  2.7   4.0  1.9  1.5  0.4  1.7  2.6  11.1
#
# [10 rows x 29 columns]

# %% [markdown]
# <h3> Now we are looking at average age </h3>

# %%
#checking what is the average number of games played 
print("Average Age is: " + str(all_players_df['AGE'].mean()))

#tor_players_df.hist(column='GP').show()
plt.style.use('fivethirtyeight')

#making the plot 
gamesPlayedHist, g = plt.subplots()

g.hist(all_players_df['AGE'],color='red',rwidth=0.25)
g.set_xlabel("Games Played")
g.set_ylabel("Number of Players")
g.set_title("Distribution of Player Ages")
g.plot()
# Out:
# Average Age is: 26.31246490735542
# []

# %% [markdown]
#    <h3> NA represents dataframe not adjusted minutes wise </h3>

# %%
#adding true shooting 3PAr and FTr to our data frame that is not adjusted per 36
all_players_NA_df = add_true_shooting(add_3PAr(add_FTr(all_players_df )))
all_players_NA_df.head(20)
# Out:
#                      NAME  TEAM  POS  AGE   G  GS    MP   FG   FGA    FG%  \
# 0              Quincy Acy   NYK   PF   24  68  22  18.9  2.2   4.9   .459
# 1            Jordan Adams   MEM   SG   20  30   0   8.3  1.2   2.9   .407
# 2            Steven Adams   OKC    C   21  70  67  25.3  3.1   5.7   .544
# 3             Jeff Adrien   MIN   PF   28  17   0  12.6  1.1   2.6   .432
# 4           Arron Afflalo   TOT   SG   29  78  72  32.1  4.8  11.3   .424
# 7           Alexis Ajinça   NOP    C   26  68   8  14.1  2.7   4.8   .550
# 8          Furkan Aldemir   PHI   PF   23  41   9  13.2  1.0   1.9   .513
# 9            Cole Aldrich   NYK    C   26  61  16  16.0  2.4   4.9   .478
# 10      LaMarcus Aldridge   POR   PF   29  71  71  35.4  9.3  19.9   .466
# 11            Lavoy Allen   IND    C   25  63   0  17.0  2.2   4.7   .472
# 12             Tony Allen   MEM   SG   33  63  41  26.2  3.6   7.2   .495
# 13        Al-Farouq Aminu   DAL   SF   24  74   3  18.5  2.0   4.8   .412
# 14           Lou Amundson   TOT   PF   32  53  35  17.7  2.1   4.8   .427
# 17         Chris Andersen   MIA    C   36  60  20  18.9  2.0   3.5   .580
# 18          Alan Anderson   BRK   SG   32  74  19  23.6  2.6   5.9   .443
# 19          Kyle Anderson   SAS   SF   21  33   8  10.8  0.9   2.7   .348
# 20          Ryan Anderson   NOP   PF   26  61   5  27.5  4.8  12.0   .399
# 21  Giannis Antetokounmpo   MIL   SG   20  81  71  31.4  4.7   9.6   .491
# 22        Carmelo Anthony   NYK   SF   30  40  40  35.7  9.0  20.2   .444
# 23           Joel Anthony   DET    C   32  49   0   8.3  0.7   1.3   .581
#
#     ...   TRB  AST  STL  BLK  TOV   PF   PTS       FTr      3PAr        TS
# 0   ...   4.4  1.0  0.4  0.3  0.9  2.2   5.9  0.285714  0.183673  0.534808
# 1   ...   0.9  0.5  0.5  0.2  0.5  0.8   3.1  0.275862  0.275862  0.476630
# 2   ...   7.5  0.9  0.5  1.2  1.4  3.2   7.7  0.508772  0.000000  0.551892
# 3   ...   4.5  0.9  0.2  0.5  0.5  1.8   3.5  0.846154  0.000000  0.490471
# 4   ...   3.2  1.7  0.5  0.1  1.5  2.1  13.3  0.221239  0.380531  0.536290
# 7   ...   4.6  0.7  0.3  0.8  1.0  2.2   6.5  0.312500  0.000000  0.595238
# 8   ...   4.3  0.7  0.4  0.4  0.4  2.3   2.3  0.368421  0.052632  0.520833
# 9   ...   5.5  1.2  0.6  1.1  1.0  2.0   5.5  0.204082  0.000000  0.514981
# 10  ...  10.2  1.7  0.7  1.0  1.7  1.8  23.4  0.256281  0.075377  0.528360
# 11  ...   5.1  1.2  0.2  0.7  0.6  1.6   5.0  0.148936  0.000000  0.499201
# 12  ...   4.4  1.4  2.0  0.5  1.4  2.6   8.6  0.277778  0.069444  0.532178
# 13  ...   4.6  0.8  0.9  0.8  0.7  1.9   5.6  0.333333  0.354167  0.508721
# 14  ...   5.1  1.3  0.4  1.0  1.2  2.4   4.9  0.333333  0.000000  0.445131
# 17  ...   5.0  0.7  0.4  1.0  0.7  1.5   5.3  0.542857  0.057143  0.611162
# 18  ...   2.8  1.1  0.8  0.1  0.8  2.0   7.4  0.237288  0.474576  0.567833
# 19  ...   2.2  0.8  0.5  0.2  0.3  0.8   2.2  0.148148  0.111111  0.382476
# 20  ...   4.8  0.9  0.5  0.3  1.0  1.9  13.7  0.208333  0.491667  0.522901
# 21  ...   6.7  2.6  0.9  1.0  2.1  3.1  12.7  0.447917  0.052083  0.552558
# 22  ...   6.6  3.1  1.0  0.4  2.2  2.2  24.2  0.292079  0.222772  0.530795
# 23  ...   1.9  0.1  0.2  1.0  0.2  1.1   1.8  0.307692  0.000000  0.609756
#
# [20 rows x 32 columns]

# %% [markdown]
# <h2> Finding average stats for nba players (no adjustment for minutes) </h2>

# %% [markdown]
# <h3> Finding stats that won't be used in comparison </h3>
